# %% [markdown]
# <a href="https://colab.research.google.com/github/ryaishnavedevi-ops/AI-Study-Buddy/blob/main/PyBuddy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q streamlit pyngrok google-generativeai

# %%
# %%writefile app.py

import streamlit as st
import google.generativeai as genai

# Configure Gemini API
from google.colab import userdata
genai.configure(api_key=userdata.get('GEMINI_API_KEY'))

model = genai.GenerativeModel("gemini-2.5-flash")

st.set_page_config(page_title="AI Study Buddy Yaishnave🎓", page_icon="🎓")

st.title("AI Study Buddy Yaishnave🎓")

topic = st.text_input("Enter a Topic")

option = st.selectbox(
    "Choose Activity",
    [
        "Explain Concept",
        "Real-Life Example",
        "Generate Quiz",
        "Ask Anything"
    ]
)

if st.button("Generate"):

    if topic == "":
        st.warning("Please enter a topic.")
    else:

        if option == "Explain Concept":
            prompt = f"Explain {topic} in simple language for a beginner."

        elif option == "Real-Life Example":
            prompt = f"Give one simple real-life example of {topic}."

        elif option == "Generate Quiz":
            prompt = f"Create 5 MCQs on {topic} with answers."

        else:
            prompt = topic

        response = model.generate_content(prompt)

        st.write(response.text)
# Out:
# Overwriting app.py

# %%
# !nohup streamlit run app.py --server.port 8501 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
import time
time.sleep(10)

# %%
# !cat nohup.out
# Out:
# ...
#
# 2026-07-04 12:56:10.250 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.239.194.242:8501
#
#
# ...
#
# 2026-07-04 13:14:04.477 Port 8501 is not available

# %%
# !pip install -q pyngrok

# %%
from pyngrok import ngrok


ngrok.set_auth_token("enter your ngrok key")

# %%
public_url = ngrok.connect(8501)


print(public_url)
# Out:
# NgrokTunnel: "https://unrushed-material-basket.ngrok-free.dev" -> "http://localhost:8501"
